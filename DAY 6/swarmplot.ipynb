# %%
# swarmplot :-- it is similar to voilin plot which shows the distributioon of a data

# %%
import seaborn as sns
s1=sns.load_dataset("tips")

# %%
sns.violinplot(x=s1["tip"],y=s1["smoker"])
sns.swarmplot(x=s1["tip"],y=s1["smoker"])
# Out:
# <Axes: xlabel='tip', ylabel='smoker'>
