# %%
# Jointplot:-- it is used to show distributioon of two quantative data and join the data

# %%
import seaborn as sns
s1=sns.load_dataset("tips")
sns.jointplot(x=s1["total_bill"],y=s1["tip"],kind='reg')
