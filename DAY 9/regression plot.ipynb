# %%
#Regression plot:-- it is used in ml for regression algo in which we need to predict y based on x sns.lmplot(x,y)

# %%
import seaborn as sns
s1=sns.load_dataset("tips")

# %%
sns.lmplot(x="tip",y="total_bill",data=s1,hue="day",palette="rainbow",markers='o',scatter_kws={'s':100})
