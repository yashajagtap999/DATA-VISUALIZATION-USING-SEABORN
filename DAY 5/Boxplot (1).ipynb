# %%
# boxplot:-- it is a type of categorical plot used to give mode outliers and differentiate between the numerical and categorical data

# %%
import seaborn as sns
s1=sns.load_dataset("tips")
sns.boxplot(x=s1["tip"],y=s1["sex"])
# Out:
# <Axes: xlabel='tip', ylabel='sex'>
